# %% [markdown]
# ---
# ---
#
# # <center><font color='black'>Chicken Schemes</font></center> <a class="tocSkip">
#
# ### <center><font color='black'>Nicolai Haug</font></center> <a class="tocSkip">
#
# ### <center><font color='black'>2021</font></center> <a class="tocSkip">
#
# ---
# ---

# %% [markdown]
# # Table of Contents <a class="tocSkip">
#
# * [Introduction](#introduction)
#     * [Configure Notebook](#configure)
# * [Section Two](#sec2)
# * [Boxes](#boxes)
# * [Plotting](#plots)
# * [Latex Envs](#tex)

# %% [markdown]
# # Introduction <a name="introduction"></a>
#
# This notebook contains templates for beautifying Notebooks.

# %% [markdown]
# ## Configure Notebook
#
# <div class="alert alert-block alert-info" style="background-color: white; border: 2px solid; padding: 10px">
#     <b><i class="fa fa-exclamation-circle" aria-hidden="true"></i>&nbsp; Important</b><br>
#     <p style="color: black">
#         Run the cell below to configure the notebook.
#     </p>
# <div>
# </div>
# </div>

# %%
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import seaborn as sns

from IPython.display import display
from latex_envs.latex_envs import figcaption 
from matplotlib import cm
from matplotlib import gridspec
from matplotlib.ticker import FormatStrFormatter, LinearLocator
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import default_rng

import warnings
# Comment this to turn on warnings
warnings.filterwarnings('ignore')

#plt.style.use('seaborn')
sns.set()
sns.set_context("paper")
sns.set_style("darkgrid", {"axes.facecolor": "0.95"})

# Set fontsizes in figures
params = {'legend.fontsize': 'large',
          'axes.labelsize': 'large',
          'axes.titlesize': 'large',
          'xtick.labelsize': 'large',
          'ytick.labelsize': 'large',
          'legend.fontsize': 'large',
          'legend.handlelength': 2}
plt.rcParams.update(params)
plt.rc('text', usetex=True)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

t = ax.text(0.5, 0.5, 'Text')

fonts = ['xx-small', 'x-small', 'small', 'medium', 'large', 
         'x-large', 'xx-large', 'larger', 'smaller']

for font in fonts:
    t.set_fontsize(font)
    print(font, round(t.get_fontsize(), 2))

plt.close()
# Out:
# xx-small 5.79
# x-small 6.94
# small 8.33
# medium 10.0
# large 12.0
# x-large 14.4
# xx-large 17.28
# larger 12.0
# smaller 8.33

# %% [markdown]
# # Section Two <a name="sec2"></a>
#
# This is section two.
#
# **Bold** or __bold__
#
# *Italic* or _italic_
#
# **_bold and italic_**
#
# > quote
#
# `code`
#
# or
#
# ```python
# >>> print("Greetings!")
# ```
#
# * item
# * item
#     * subitem
#
# 1. item
# 2. item
#
# **Display images:**
#
# ```
# <img src="filename.extension" width="600" height="600" align="center"/>
# ```
#
# or
#
# ```
# <img src="url.gif" alt="Alt text that describes the graphic" title="Title text" />
# ```
#
# or
#
# ```
# ![Image](image.png)
# ```
#
# **Text:**
#
# Text can be colored using html `<font color=red>` `</font>` tags:
#
# <font color=red>Red Text</font>
#
# **Links:**
#
# ```
# [GitHub directory](https://github.com/nicolossus/Master-thesis)
# ```
#
# [GitHub directory](https://github.com/nicolossus/Master-thesis)
#
# **Horizontal rule:**
#
# ***
#
# ---
#
# **Tables:**
#
# | header1 | header 2 | header 3 |
# | ------- | -------- | -------- |
# | col 1   | col 2    | col 3    |
# | col 1   | col 2    | col 3    |

# %% [markdown]
# # Boxes <a name="boxes"></a>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: white; border: 2px solid; padding: 10px">
#     <b><i class="fa fa-info-circle" aria-hidden="true"></i>&nbsp; Info</b><br>
#     <p style="color: black">
#         The Universe states that:
#     </p>
# <div>
#
# \begin{equation}
#     E = mc^2 \tag{1}
# \end{equation}
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: white; border: 2px solid; padding: 10px">
#     <b><i class="fa fa-pencil" aria-hidden="true"></i>&nbsp; Equation</b><br>
# <div>
#
# \begin{equation}
#     E = mc^2 \tag{1}
# \end{equation}
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: white; border: 2px solid; padding: 10px">
#     <b><i class="fa fa-pencil" aria-hidden="true"></i>&nbsp; Equation</b><br>
#     <p style="color: black">
#         The Universe states that:
#     </p>
# <div>
#
# \begin{equation}
#     E = mc^2 \tag{1}
# \end{equation}
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: white; border: 2px solid; padding: 10px">
#     <b><i class="fa fa-calculator" aria-hidden="true"></i>&nbsp; Algorithm</b><br>
#     <p style="color: black">
#         The Scheme:
#     </p>
# <div>
#
# 1. Initialize
# 2. Compute
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: white; border: 2px solid; padding: 10px">
#     <b><i class="fa fa-code" aria-hidden="true"></i>&nbsp; Code</b><br>
#     <p style="color: black">
#         We can also specify the order of the words within a sentence using numbers within the curly braces:
#     </p>
# <div>
#
# ```python
# >>> "Hello {1} {0}".format("Mr.", "Bond")  # explicit argument order
# 'Hello Bond Mr.'
# ```
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color: white; border: 2px solid; padding: 10px">
#     <b><i class="fa fa-bug" aria-hidden="true"></i>&nbsp; Bug</b><br>
#     <p style="color: black">
#         We can also specify the order of the words within a sentence using numbers within the curly braces:
#     </p>
# <div>
#
# ```python
# >>> "Hello {1} {0}".format("Mr.", "Bond")  # explicit argument order
# 'Hello Bond Mr.'
# ```
#
# </div>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <strong>Let's start with THIS blue box:</strong>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <strong>green for success</strong>
# </div>

# %% [markdown]
# <div class="alert alert-warning">
#   <strong>yellow, indicating a warning, or some findings that could be neutral->negative</strong>
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>red, indicating something is bad or "dangerous", negative findings.</strong>
# </div>

# %% [markdown]
# # Plotting <a name="plots"></a>

# %%
plt.legend(handlelength=5, borderpad=1.2, labelspacing=1.2)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Fill Between

# %%
rng = default_rng()

N = 100
data = []
for _ in range(20):
    data.append(rng.uniform(0, 1, N))

mean = np.mean(data, axis=0)
std = np.std(data, axis=0)

fig = plt.figure(figsize=(6, 4), tight_layout=True, dpi=120)

plt.plot(mean, lw=1.5)
plt.fill_between(range(N), mean - std, mean + std,
                 alpha=0.5, facecolor='lightblue')
plt.xlabel("Iterations")
plt.ylabel("Data")
plt.title("Fill Between")
plt.show()

# %% [markdown]
# ## Figcaption

# %%
fig = plt.figure(figsize=(6, 4), tight_layout=True, dpi=120)
plt.plot(np.sin(2 * np.pi * 0.1 * np.arange(100)), lw=2)
plt.show()
figcaption("This is a nice sine wave", label="fig:mysin")
# Out:
# <div class=caption><b> Caption: </b> This is a nice sine wave</div>

# %% [markdown]
# ## Grids and Legend

# %%
rng = default_rng()

N = 3
data = rng.laplace(loc=15, scale=3, size=(100, N))

fig = plt.figure(figsize=(8, 4), tight_layout=True, dpi=120)

cols = 3
rows = int(np.ceil(N / cols))
gs = gridspec.GridSpec(ncols=cols, nrows=rows, figure=fig)

for index in range(N):
    ax = fig.add_subplot(gs[index])
    ax.hist(data[:, index], density=True, histtype='bar', edgecolor=None,
                color='steelblue', alpha=0.9, label="Samples") 
    ax.set_xlabel(r"$\hat{\theta}$")
    ax.set_title(r"Histogram of sampled $\theta$")

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, 
           labels, 
           loc='center left', 
           bbox_to_anchor=(1.04, 0.5),
           fancybox=True,
           borderaxespad=0.1,
           ncol=1
           )
plt.show()

# %%
rng = default_rng()

N = 6
data = rng.laplace(loc=15, scale=3, size=(100, N))

fig = plt.figure(figsize=(8, 6), tight_layout=True, dpi=120)

cols = 3
rows = int(np.ceil(N / cols))
gs = gridspec.GridSpec(ncols=cols, nrows=rows, figure=fig)

for index in range(N):
    ax = fig.add_subplot(gs[index])
    ax.hist(data[:, index], density=True, histtype='bar', edgecolor=None,
                color='steelblue', alpha=0.9, label="Samples") 
    ax.set_xlabel(r"$\theta$")
    ax.set_title(r"Histogram of sampled $\theta$")
    
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, 
           labels, 
           loc='center left', 
           bbox_to_anchor=(1.04, 0.5),
           fancybox=True,
           borderaxespad=0.1,
           ncol=1
           )
plt.show()

# %%
rng = default_rng()

N = 9
data = rng.laplace(loc=15, scale=3, size=(100, N))

fig = plt.figure(figsize=(8, 6), tight_layout=True, dpi=120)

cols = 3
rows = int(np.ceil(N / cols))
gs = gridspec.GridSpec(ncols=cols, nrows=rows, figure=fig)

for index in range(N):
    ax = fig.add_subplot(gs[index])
    ax.hist(data[:, index], density=True, histtype='bar', edgecolor=None,
                color='steelblue', alpha=0.9, label="Samples") 
    ax.set_xlabel(r"$\theta$")
    ax.set_title(r"Histogram of sampled $\theta$")

handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, 
           labels, 
           loc='center left', 
           bbox_to_anchor=(1.04, 0.5),
           fancybox=True,
           borderaxespad=0.1,
           ncol=1
           )
plt.show()

# %%
rng = default_rng()

N = 1
data = rng.laplace(loc=15, scale=3, size=(100, N))
sns.displot(data[:, 0], kde=True)

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 16,
        }

x = np.linspace(0.0, 5.0, 100)
y = np.cos(2*np.pi*x) * np.exp(-x)

plt.plot(x, y, 'k')
plt.title('Damped exponential decay', fontdict=font)
plt.text(2, 0.65, r'$\cos(2 \pi t) \exp(-t)$', fontdict=font)
plt.xlabel('time (s)', fontdict=font)
plt.ylabel('voltage (mV)', fontdict=font)

# Tweak spacing to prevent clipping of ylabel
plt.subplots_adjust(left=0.15)
plt.show()

# %%
fig = plt.figure(figsize=(8, 4), dpi=120)
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
val = 0.5
plt.plot(x, y, label=r"$\hat{{\tau}}$={:.2f}".format(val))
plt.legend()
plt.show()

# %% [markdown]
# # Latex Envs <a name="tex"></a>
